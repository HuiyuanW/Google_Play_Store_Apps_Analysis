# %% [markdown]
# # Total Estimated Revenue: \\$290M+
#
# ### Breakdown by Category
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Highest Revenue App in Each Category (Top10)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Top10 Revenue App (~ 60% of total revenue)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Revenue vs App Price
# ![image.png](attachment:image.png)

# %% [markdown]
# # Total Number of Installs: 75 billion+
# ### Breakdown by Category
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Number of Installs of Paid vs Free Apps in each Category
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Paid vs Free Apps
# ![image.png](attachment:image.png)

# %% [markdown]
# # Most Popular Apps
#
# ## Overall (Top 15, Ordered by Installs Desending, Rating Descending)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### If only rating considered, high rating mostly due to low number of reviews
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Most Popular Paid App (Top 10, Ordered by Installs Desending, Rating Descending)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Rating Distribution - Free vs Paid Apps
# ![image.png](attachment:image.png)
