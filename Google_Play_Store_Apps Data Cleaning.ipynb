# %% [markdown]
# ## Google Play Store Apps Dataset Cleaning and Feature Engineering
#
# Web scraped data of 10k Play Store apps for analysing the Android market. Source: https://www.kaggle.com/lava18/google-play-store-apps
#
# Fields in the data:
# * App: Application name
# * Category: Category to which the app belongs
# * Rating: Overall user rating of the app
# * Reviews: Number of user reviews for the app
# * Size: Size of the app
# * Installs: Number of user downloads/installs for the app
# * Type: Paid or Free
# * Price: Price of the app
# * Content Rating: Age group the app is targeted at - Children / Mature 21+ / Adult
# * Genres: An app can belong to multiple genres (apart from its main category). For example, a musical family game will belong to Music, Game, Family genres.
# * Last Updated: Date when the app was last updated on Play Store
# * Current Ver: Current version of the app available on Play Store
# * Android Ver: Minimum required Android version

# %%
import pandas as pd

#playstore_data = pd.read_csv('/home/whuiyuan3/Data_Science_Projects/Google_PlayStore_Apps/googleplaystore.csv')
playstore_data = pd.read_csv('./googleplaystore.csv', parse_dates=['Last Updated']).drop_duplicates()
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
playstore_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10358 non-null object
# Category          10358 non-null object
# Rating            8893 non-null float64
# Reviews           10358 non-null object
# Size              10358 non-null object
# Installs          10358 non-null object
# Type              10357 non-null object
# Price             10358 non-null object
# Content Rating    10357 non-null object
# Genres            10358 non-null object
# Last Updated      10358 non-null object
# Current Ver       10350 non-null object
# Android Ver       10355 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
playstore_data.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
playstore_data.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
playstore_data.Size.unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M', '2.2M',
#        '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M', '7.1M',
#        '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M', '4.9M',
#        '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M',
#        '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M', '23k', '6.5M',
#        '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M', '8.3M', '4.3M',
#        '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M',
#        '79k', '8.4M', '118k', '44M', '695k', '1.6M', '6.2M', '18k', '53M',
#        '1.4M', '3.0M', '5.8M', '3.8M', '9.6M', '45M', '63M', '49M', '77M',
#        '4.4M', '4.8M', '70M', '6.9M', '9.3M', '10.0M', '8.1M', '36M',
#        '84M', '97M', '2.0M', '1.9M', '1.8M', '5.3M', '47M', '556k', '526k',
#        '76M', '7.6M', '59M', '9.7M', '78M', '72M', '43M', '7.7M', '6.3M',
#        '334k', '34M', '93M', '65M', '79M', '100M', '58M', '50M', '68M',
#        '64M', '67M', '60M', '94M', '232k', '99M', '624k', '95M', '8.5k',
#        '41k', '292k', '11k', '80M', '1.7M', '74M', '62M', '69M', '75M',
#        '98M', '85M', '82M', '96M', '87M', '71M', '86M', '91M', '81M',
#        '92M', '83M', '88M', '704k', '862k', '899k', '378k', '266k', '375k',
#        '1.3M', '975k', '980k', '4.1M', '89M', '696k', '544k', '525k',
#        '920k', '779k', '853k', '720k', '713k', '772k', '318k', '58k',
#        '241k', '196k', '857k', '51k', '953k', '865k', '251k', '930k',
#        '540k', '313k', '746k', '203k', '26k', '314k', '239k', '371k',
#        '220k', '730k', '756k', '91k', '293k', '17k', '74k', '14k', '317k',
#        '78k', '924k', '902k', '818k', '81k', '939k', '169k', '45k', '475k',
#        '965k', '90M', '545k', '61k', '283k', '655k', '714k', '93k', '872k',
#        '121k', '322k', '1.0M', '976k', '172k', '238k', '549k', '206k',
#        '954k', '444k', '717k', '210k', '609k', '308k', '705k', '306k',
#        '904k', '473k', '175k', '350k', '383k', '454k', '421k', '70k',
#        '812k', '442k', '842k', '417k', '412k', '459k', '478k', '335k',
#        '782k', '721k', '430k', '429k', '192k', '200k', '460k', '728k',
#        '496k', '816k', '414k', '506k', '887k', '613k', '243k', '569k',
#        '778k', '683k', '592k', '319k', '186k', '840k', '647k', '191k',
#        '373k', '437k', '598k', '716k', '585k', '982k', '222k', '219k',
#        '55k', '948k', '323k', '691k', '511k', '951k', '963k', '25k',
#        '554k', '351k', '27k', '82k', '208k', '913k', '514k', '551k', '29k',
#        '103k', '898k', '743k', '116k', '153k', '209k', '353k', '499k',
#        '173k', '597k', '809k', '122k', '411k', '400k', '801k', '787k',
#        '237k', '50k', '643k', '986k', '97k', '516k', '837k', '780k',
#        '961k', '269k', '20k', '498k', '600k', '749k', '642k', '881k',
#        '72k', '656k', '601k', '221k', '228k', '108k', '940k', '176k',
#        '33k', '663k', '34k', '942k', '259k', '164k', '458k', '245k',
#        '629k', '28k', '288k', '775k', '785k', '636k', '916k', '994k',
#        '309k', '485k', '914k', '903k', '608k', '500k', '54k', '562k',
#        '847k', '957k', '688k', '811k', '270k', '48k', '329k', '523k',
#        '921k', '874k', '981k', '784k', '280k', '24k', '518k', '754k',
#        '892k', '154k', '860k', '364k', '387k', '626k', '161k', '879k',
#        '39k', '970k', '170k', '141k', '160k', '144k', '143k', '190k',
#        '376k', '193k', '246k', '73k', '658k', '992k', '253k', '420k',
#        '404k', '1,000+', '470k', '226k', '240k', '89k', '234k', '257k',
#        '861k', '467k', '157k', '44k', '676k', '67k', '552k', '885k',
#        '1020k', '582k', '619k'], dtype=object)

# %%
playstore_data.Size.value_counts()
# Out:
# Varies with device    1526
# 11M                    188
# 13M                    186
# 12M                    186
# 14M                    182
# 15M                    174
# 17M                    155
# 26M                    145
# 16M                    143
# 19M                    135
# 10M                    133
# 25M                    131
# 20M                    131
# 21M                    130
# 24M                    129
# 18M                    124
# 23M                    109
# 22M                    108
# 29M                     95
# 27M                     94
# 28M                     92
# 30M                     84
# 33M                     78
# 3.3M                    76
# 37M                     72
# 31M                     69
# 35M                     68
# 2.5M                    68
# 2.3M                    68
# 2.9M                    67
#                       ...
# 608k                     1
# 191k                     1
# 20k                      1
# 785k                     1
# 892k                     1
# 511k                     1
# 676k                     1
# 865k                     1
# 976k                     1
# 108k                     1
# 853k                     1
# 874k                     1
# 951k                     1
# 470k                     1
# 730k                     1
# 14k                      1
# 778k                     1
# 161k                     1
# 992k                     1
# 812k                     1
# 913k                     1
# 288k                     1
# 787k                     1
# 210k                     1
# 552k                     1
# 116k                     1
# 601k                     1
# 872k                     1
# 924k                     1
# 655k                     1
# Name: Size, Length: 462, dtype: int64

# %%
# delete rows with wrong data 
playstore_data = playstore_data[playstore_data.Size != '1,000+']
# convert kB to MB 
playstore_data['Size'] = playstore_data['Size'].apply(lambda x: str(x).replace('k','e-3').strip('M'))
playstore_data['Size(M)'] = pd.to_numeric(playstore_data['Size'], errors = 'coerce' ) #coerce substitute string "Varies with device" to NaN

# %%
playstore_data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
playstore_data['Installs'] = playstore_data['Installs'].apply(lambda x: x.strip('+').replace(',',''))
playstore_data.Installs = pd.to_numeric(playstore_data.Installs)
playstore_data.Reviews = pd.to_numeric(playstore_data.Reviews)

# %%
playstore_data.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
playstore_data.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# Size(M)           1526
# dtype: int64

# %%
playstore_data['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$1.00',
#        '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99',
#        '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70', '$8.99',
#        '$2.00', '$3.88', '$25.99', '$399.99', '$17.99', '$400.00', '$3.02',
#        '$1.76', '$4.84', '$4.77', '$1.61', '$2.50', '$1.59', '$6.49',
#        '$1.29', '$5.00', '$13.99', '$299.99', '$379.99', '$37.99',
#        '$18.99', '$389.99', '$19.90', '$8.49', '$1.75', '$14.00', '$4.85',
#        '$46.99', '$109.99', '$154.99', '$3.08', '$2.59', '$4.80', '$1.96',
#        '$19.40', '$3.90', '$4.59', '$15.46', '$3.04', '$4.29', '$2.60',
#        '$3.28', '$4.60', '$28.99', '$2.95', '$2.90', '$1.97', '$200.00',
#        '$89.99', '$2.56', '$30.99', '$3.61', '$394.99', '$1.26', '$1.20',
#        '$1.04'], dtype=object)

# %%
playstore_data.Price = playstore_data.Price.apply(lambda x: x.strip('$'))
playstore_data['Price($)'] = pd.to_numeric(playstore_data.Price)
playstore_data = playstore_data.drop(columns = ['Size','Price'])

# %%
playstore_data[playstore_data['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1    20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2     4010
# 6803                         BT Master               FAMILY     NaN        0
# 7333                       Dots puzzle               FAMILY     4.0      179
# 7407                   Calculate My IQ               FAMILY     NaN       44
# 7730                            UFO-CQ                TOOLS     NaN        1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN        8
#
#        Installs  Type Content Rating             Genres       Last Updated  \
# 15         5000  Free       Everyone       Art & Design       June 6, 2018
# 1553    1000000  Free       Everyone   Libraries & Demo  February 12, 2013
# 6322     500000  Free       Everyone              Tools       May 10, 2017
# 6803        100  Free       Everyone          Education   November 6, 2016
# 7333      50000  Paid       Everyone             Puzzle     April 18, 2018
# 7407      10000  Free       Everyone      Entertainment      April 3, 2017
# 7730         10  Paid       Everyone              Tools       July 4, 2016
# 10342      1000  Free       Everyone  Books & Reference   January 31, 2017
#
#       Current Ver Android Ver  Size(M)  Price($)
# 15            NaN  4.2 and up    2.700      0.00
# 1553          NaN  1.5 and up    0.011      0.00
# 6322          NaN  4.0 and up    8.700      0.00
# 6803          NaN  1.6 and up    0.222      0.00
# 7333          NaN  4.0 and up   14.000      0.99
# 7407          NaN  2.3 and up    7.200      0.00
# 7730          NaN  2.0 and up    0.237      0.99
# 10342         NaN  3.0 and up    0.658      0.00

# %%
playstore_data['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'], dtype=object)

# %%
playstore_data['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
playstore_data['Android Ver'].value_counts()
# Out:
# 4.1 and up            2379
# 4.0.3 and up          1451
# 4.0 and up            1337
# Varies with device    1221
# 4.4 and up             894
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 5.0 - 8.0                2
# 1.0 and up               2
# 4.0.3 - 7.1.1            2
# 2.2 - 7.1.1              1
# 5.0 - 6.0                1
# 7.0 - 7.1.1              1
# 5.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
playstore_data['Android Ver req'] = playstore_data['Android Ver'].apply(lambda x: str(x).split('and')[0].split('-')[0].replace('W',''))
playstore_data['Android Ver req'].value_counts()
# Out:
# 4.1                   2380
# 4.0.3                 1453
# 4.0                   1337
# Varies with device    1221
# 4.4                    905
# 2.3                    643
# 5.0                    550
# 4.2                    387
# 2.3.3                  279
# 2.2                    240
# 3.0                    237
# 4.3                    235
# 2.1                    133
# 1.6                    116
# 6.0                     58
# 7.0                     43
# 3.2                     36
# 2.0                     32
# 5.1                     22
# 1.5                     20
# 3.1                     10
# 2.0.1                    7
# 8.0                      6
# 7.1                      3
# 1.0                      2
# nan                      2
# Name: Android Ver req, dtype: int64

# %%
playstore_data.describe()
# Out:
#             Rating       Reviews      Installs      Size(M)      Price($)
# count  8892.000000  1.035700e+04  1.035700e+04  8831.000000  10357.000000
# mean      4.187877  4.059046e+05  1.415776e+07    21.287788      1.030800
# std       0.522377  2.696778e+06  8.023955e+07    22.540247     16.278625
# min       1.000000  0.000000e+00  0.000000e+00     0.008500      0.000000
# 25%       4.000000  3.200000e+01  1.000000e+03     4.700000      0.000000
# 50%       4.300000  1.680000e+03  1.000000e+05    13.000000      0.000000
# 75%       4.500000  4.641600e+04  1.000000e+06    29.000000      0.000000
# max       5.000000  7.815831e+07  1.000000e+09   100.000000    400.000000

# %%
playstore_data.App.value_counts()
# Out:
# ROBLOX                                                9
# 8 Ball Pool                                           7
# Bubble Shooter                                        6
# Helix Jump                                            6
# Zombie Catchers                                       6
# Granny                                                5
# Subway Surfers                                        5
# Angry Birds Classic                                   5
# Duolingo: Learn Languages Free                        5
# Zombie Tsunami                                        5
# slither.io                                            5
# Candy Crush Saga                                      5
# Temple Run 2                                          5
# Farm Heroes Saga                                      5
# Bowmasters                                            5
# Sniper 3D Gun Shooter: Free Shooting Games - FPS      4
# Google Photos                                         4
# Word Search                                           4
# Flow Free                                             4
# Angry Birds Rio                                       4
# BeautyPlus - Easy Photo Editor & Selfie Camera        4
# Wish - Shopping Made Fun                              4
# AliExpress - Smarter Shopping, Better Living          4
# Viber Messenger                                       4
# Netflix                                               4
# Zombie Hunter King                                    4
# My Talking Angela                                     4
# Talking Tom Gold Run                                  4
# YouTube Kids                                          4
# Yahoo Fantasy Sports - #1 Rated Fantasy App           4
#                                                      ..
# Keepsafe Photo Vault: Hide Private Photos & Videos    1
# Patient Portal                                        1
# Dulquer Salmaan HD Wallpapers                         1
# Micro Fi                                              1
# Guide (for X-MEN)                                     1
# AH Connect (Adventist Health)                         1
# Experiment Z - Zombie                                 1
# Eyewitness Travel Phrase Book                         1
# Facebook Creator                                      1
# Blidz - Hunt Free Deals On Trending Items!            1
# Fantastic Chefs: Match 'n Cook                        1
# OE TRACKER CE Attendance App                          1
# Google Play Movies & TV                               1
# Unicorn Pokez - Color By Number                       1
# Daily DM                                              1
# Bits Watch Face                                       1
# DF BugMeNot                                           1
# Injustice: Gods Among Us                              1
# CP Parquet                                            1
# CT Sessions                                           1
# EF/VR – VR Tours of EF Schools                        1
# Moven - Smart Finances                                1
# Harley Quinn wallpapers HD                            1
# Wallpapers FN FAL Light Automatic Rifle               1
# Le Fe de Jesus                                        1
# AP Flashcards                                         1
# Baby puzzles                                          1
# РИА Новости                                           1
# Nights at Cube Pizzeria 3D – 4                        1
# Dubai Racing                                          1
# Name: App, Length: 9659, dtype: int64

# %%
playstore_data.groupby('App').filter(lambda x: len(x)>1)
# Out:
#                                                      App             Category  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 139                                 Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# 143                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 145                         Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE
# 146                        NOOK: Read eBooks & Magazines  BOOKS_AND_REFERENCE
# 155                  Oxford Dictionary of English : Free  BOOKS_AND_REFERENCE
# 157                           Spanish English Translator  BOOKS_AND_REFERENCE
# 162                            NOOK App for NOOK Devices  BOOKS_AND_REFERENCE
# 186                         English Dictionary - Offline  BOOKS_AND_REFERENCE
# 194               OfficeSuite : Free Office + PDF Editor             BUSINESS
# 197    Curriculum vitae App CV Builder Free Resume Maker             BUSINESS
# 201                               Facebook Pages Manager             BUSINESS
# 206                                         Call Blocker             BUSINESS
# 215                                 Facebook Ads Manager             BUSINESS
# 222                         Quick PDF Scanner + OCR FREE             BUSINESS
# 294                           Business     August 2, 2018  Varies with device
# 297                             Comics      July 31, 2018  Varies with device
# 312                             Comics       May 18, 2018                 1.0
# 315                             Comics       June 5, 2018  Varies with device
# 325                             Comics      July 24, 2018               1.0.4
# 335                      Communication     August 1, 2018  Varies with device
# 336                      Communication     August 3, 2018  Varies with device
# 338                      Communication     August 1, 2018  Varies with device
# ...                                ...                ...                 ...
# 9844                  News & Magazines     August 1, 2018               5.2.0
# 9853                            Social     August 7, 2018           1.8.19179
# 9854                  Health & Fitness      July 18, 2018              5.14.0
# 9856                     Communication  September 2, 2015       0.1.100944346
# 9859                    Travel & Local       June 7, 2018              17.4.1
# 9936               Casual;Pretend Play   November 6, 2017                 1.2
# 9975                  Health & Fitness      June 28, 2018  Varies with device
# 9982                      House & Home       July 6, 2018  Varies with device
# 10018                    Entertainment      July 27, 2018  Varies with device
# 10026                    Communication      June 20, 2018                 2.2
# 10118                      Photography     March 15, 2017               2.0.5
# 10170                           Social       June 4, 2018                1.24
# 10171                           Social       May 21, 2018              2.4.12
# 10178                           Sports     August 7, 2018               1.1.5
# 10186                           Casual     August 7, 2018               5.2.6
# 10188                           Sports  November 21, 2017               5.3.0
# 10190                       Simulation      June 11, 2018             1.13.12
# 10200                         Business     August 6, 2018  Varies with device
# 10203                         Business     August 1, 2018        99.0.0.35.75
# 10213                           Social      June 24, 2018               4.1.1
# 10269                           Sports      July 31, 2018             1.2.677
# 10327                           Action     August 3, 2018              1.21.0
# 10473                            Tools     August 7, 2018             6.06.14
# 10502        Racing;Action & Adventure     August 7, 2018                3.53
# 10646                 News & Magazines      July 25, 2018            4.1.0.72
# 10647          Video Players & Editors        May 2, 2018  Varies with device
# 10715                           Dating  February 25, 2016                 2.2
# 10720                    Communication       July 6, 2018                 5.2
# 10730                          Medical     March 24, 2018           2.1.0.372
# 10753                         Shopping      July 30, 2018                 3.9
#
#               Android Ver  Size(M)  Price($)     Android Ver req
# 1            4.0.3 and up   14.000       0.0              4.0.3
# 23             4.1 and up    7.000       0.0                4.1
# 36             4.4 and up   24.000       0.0                4.4
# 42     Varies with device      NaN       0.0  Varies with device
# 139    Varies with device      NaN       0.0  Varies with device
# 143    Varies with device      NaN       0.0  Varies with device
# 145    Varies with device      NaN       0.0  Varies with device
# 146    Varies with device      NaN       0.0  Varies with device
# 155            4.1 and up    7.100       0.0                4.1
# 157    Varies with device      NaN       0.0  Varies with device
# 162    Varies with device      NaN       0.0  Varies with device
# 186            4.2 and up   30.000       0.0                4.2
# 194            4.1 and up   35.000       0.0                4.1
# 197            4.1 and up    3.900       0.0                4.1
# 201    Varies with device      NaN       0.0  Varies with device
# 206            4.0 and up    3.200       0.0                4.0
# 215            4.1 and up      NaN       0.0                4.1
# 222          4.0.3 and up      NaN       0.0              4.0.3
# 238          4.0.3 and up   20.000       0.0              4.0.3
# 240    Varies with device      NaN       0.0  Varies with device
# 285          4.0.3 and up      NaN       0.0              4.0.3
# 293            4.1 and up   35.000       0.0                4.1
# 294    Varies with device      NaN       0.0  Varies with device
# 297    Varies with device      NaN       0.0  Varies with device
# 312          4.0.3 and up    7.100       0.0              4.0.3
# 315    Varies with device      NaN       0.0  Varies with device
# 325          4.0.3 and up    4.700       0.0              4.0.3
# 335    Varies with device      NaN       0.0  Varies with device
# 336    Varies with device      NaN       0.0  Varies with device
# 338    Varies with device      NaN       0.0  Varies with device
# ...                   ...      ...       ...                 ...
# 9844           4.4 and up   13.000       0.0                4.4
# 9853         4.0.3 and up   62.000       0.0              4.0.3
# 9854           5.0 and up   93.000       0.0                5.0
# 9856         4.0.3 and up    0.079       0.0              4.0.3
# 9859         4.0.3 and up   33.000       0.0              4.0.3
# 9936           4.1 and up   15.000       0.0                4.1
# 9975   Varies with device   15.000       0.0  Varies with device
# 9982   Varies with device      NaN       0.0  Varies with device
# 10018  Varies with device      NaN       0.0  Varies with device
# 10026          4.0 and up    4.300       0.0                4.0
# 10118          4.0 and up    9.600       0.0                4.0
# 10170          4.1 and up    4.000       0.0                4.1
# 10171          4.0 and up    1.500       0.0                4.0
# 10178          4.1 and up   24.000       0.0                4.1
# 10186          2.3 and up   71.000       0.0                2.3
# 10188          4.4 and up   10.000       0.0                4.4
# 10190          4.1 and up   25.000       0.0                4.1
# 10200  Varies with device      NaN       0.0  Varies with device
# 10203          4.1 and up      NaN       0.0                4.1
# 10213        4.0.3 and up    9.900       0.0              4.0.3
# 10269          4.4 and up   17.000       0.0                4.4
# 10327        4.0.3 and up   53.000       0.0              4.0.3
# 10473          4.4 and up    4.100       0.0                4.4
# 10502          4.2 and up      NaN       0.0                4.2
# 10646          4.0 and up   19.000       0.0                4.0
# 10647  Varies with device      NaN       0.0  Varies with device
# 10715          4.0 and up    1.400       0.0                4.0
# 10720          5.0 and up    4.000       0.0                5.0
# 10730          4.4 and up   60.000       0.0                4.4
# 10753          4.4 and up   12.000       0.0                4.4
#
# [1221 rows x 14 columns]

# %%
# delete redundant rows - all other columns the same, but number of Reviews vary --> keep the max

m_idx = playstore_data.groupby('App')['Reviews'].idxmax()
playstore_data= playstore_data.loc[m_idx].reset_index(drop=True)
playstore_data.head()
#potential issue, one game may be under different category
# Out:
#                                     App       Category  Rating  Reviews  \
# 0  "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN       27
# 1         +Download 4 Instagram Twitter         SOCIAL     4.5    40467
# 2            - Free Comics - Comic Apps         COMICS     3.5      115
# 3                                    .R          TOOLS     4.5      259
# 4                                /u/app  COMMUNICATION     4.7      573
#
#    Installs  Type Content Rating         Genres        Last Updated  \
# 0       500  Free       Everyone         Sports     October 7, 2017
# 1   1000000  Free       Everyone         Social      August 2, 2018
# 2     10000  Free     Mature 17+         Comics       July 13, 2018
# 3     10000  Free       Everyone          Tools  September 16, 2014
# 4     10000  Free     Mature 17+  Communication        July 3, 2018
#
#   Current Ver Android Ver  Size(M)  Price($) Android Ver req
# 0        0.22  4.1 and up    3.600       0.0            4.1
# 1        5.03  4.1 and up   22.000       0.0            4.1
# 2      5.0.12  5.0 and up    9.100       0.0            5.0
# 3      1.1.06  1.5 and up    0.203       0.0            1.5
# 4       4.2.4  4.1 and up   53.000       0.0            4.1

# %%
playstore_data['Revenue_est($)'] = playstore_data['Price($)']*playstore_data['Installs']

# %%
playstore_data.to_csv('./gpsa.csv')
